# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/Colab_Notebooks/CSC8639/fewshot_foodseg103')

# %%
# !pip install segmentation_models_pytorch
# Out:
# Collecting segmentation_models_pytorch
#   Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: huggingface-hub>=0.24 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (0.34.1)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (2.0.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (11.3.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (0.5.3)
# Requirement already satisfied: timm>=0.9 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (1.0.19)
# Requirement already satisfied: torch>=1.8 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (1.1.5)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8->segmentation_models_pytorch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8->segmentation_models_pytorch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.24->segmentation_models_pytorch) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.24->segmentation_models_pytorch) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.24->segmentation_models_pytorch) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.24->segmentation_models_pytorch) (2025.7.14)
# Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 16.6 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 130.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 104.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 42.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 105.2 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, segmentation_models_pytorch
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 segmentation_models_pytorch-0.5.0

# %%
# Train
# FoodSeg103

args = [
    '--split_class_json', '../data/foodseg103/class_split.json',
    '--class2images_mapping_json', '../data/foodseg103/class2images_mapping.json',
    '--img_dir', '../data/foodseg103/rawdata/image',
    '--mask_dir', '../data/foodseg103/rawdata/mask',

    '--model_name', 'resnet50_8x_cosine_accu_bgmix_scaler',  # 选择模型时更改
    '--seed', '42',
    '--beta_mix', '0.5',
    '--alpha_bg', '1',

    '--n_way', '1',
    '--k_shot', '5',
    '--q_query', '5',
    '--train_episodes', '100',
    '--val_episodes', '50',

    '--batch_size', '1',
    '--num_workers', '10',
    '--epochs', '50',

    '--optimizer', 'adamw',  # adam/adamw/sgd
    '--scheduler', 'cosine',  # step/cosine/cosine_restart/plateau
    '--learning_rate', '1e-3',
    '--weight_decay', '1e-4',
    '--loss', 'ce',  # ce/dice/focal/combo
    # '--bg_weight', '0.8',  # loss中背景类别权重（已在trainshell中禁用）
    '--metric', 'miou', 'dice', 'precision', 'recall', 'acc',  # 启用的metrics

    '--main_metric', 'miou',  # loss/miou/dice/acc  # 指定监控指标（默认为loss），最佳模型保存策略、plateau学习率下降策略、早停策略共用此指标
    # '--early_stopping_patience', '25',  # 设置早停轮数即启用早停

    # '--weight_path',  # 预训练模型/上次训练模型 路径
    # '--is_resume',  # 断点训练
    '--use_amp',

    '--save_dir', 'result_foodseg103/resnet50_8x_cosine_accu_bgmix05_scaler1',  # 每次更改，与 wandb 项目名相同
    '--wandb'  # 设置即启用
    ]

# !python train_shell.py {' '.join(args)}
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: ltc735983415 (ltc735983415-newcastle-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /content/drive/.shortcut-targets-by-id/1fuvwH2wo3q3zusv_klINh1muke4KOxCQ/Colab_Notebooks/CSC8639/fewshot_foodseg103/wandb/run-20250729_230329-k97eh69e
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run resnet50_8x_cosine_accu_bgmix05_scaler1
# wandb: ⭐️ View project at https://wandb.ai/ltc735983415-newcastle-university/CSC8639_FewShot_FoodSeg103
# wandb: 🚀 View run at https://wandb.ai/ltc735983415-newcastle-university/CSC8639_FewShot_FoodSeg103/runs/k97eh69e
# Start training New Model
# [CONFIG] n_way=1, k_shot=5, q_query=5, train_episodes=100, val_episodes=50
#
#
#
# [Epoch 1/50]
# Epoch 1: train_loss=0.4052, val_loss=0.3751, miou=0.0046, dice=0.0091, precision=0.2646, recall=0.0047, acc=0.0047
# Current learning rate: [0.0009990232305719944]
# Model saved to result_foodseg103/resnet50_8x_cosine_accu_bgmix05_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 2/50]
# Epoch 2: train_loss=0.3611, val_loss=0.4066, miou=0.0006, dice=0.0012, precision=0.0214, recall=0.0007, acc=0.0007
# Current learning rate: [0.0009960967771506664]
#
# [Epoch 3/50]
# Epoch 3: train_loss=0.3612, val_loss=0.3666, miou=0.0034, dice=0.0063, precision=0.1646, recall=0.0036, acc=0.0036
# Current learning rate: [0.0009912321891107007]
#
# [Epoch 4/50]
# Epoch 4: train_loss=0.3703, val_loss=0.3460, miou=0.0520, dice=0.0946, precision=0.4599, recall=0.0595, acc=0.0595
# Current learning rate: [0.0009844486647586721]
# Model saved to result_foodseg103/resnet50_8x_cosine_accu_bgmix05_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 5/50]
# Epoch 5: train_loss=0.3139, val_loss=0.3220, miou=0.0674, dice=0.1167, precision=0.4867, recall=0.0756, acc=0.0756
# Current learning rate: [0.0009757729755661009]
# Model saved to result_foodseg103/resnet50_8x_cosine_accu_bgmix05_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 6/50]
# Epoch 6: train_loss=0.3253, val_loss=0.3434, miou=0.0696, dice=0.1210, precision=0.5003, recall=0.0817, acc=0.0817
# Current learning rate: [0.0009652393605146842]
# Model saved to result_foodseg103/resnet50_8x_cosine_accu_bgmix05_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 7/50]
# Epoch 7: train_loss=0.3479, val_loss=0.3591, miou=0.0021, dice=0.0040, precision=0.2538, recall=0.0021, acc=0.0021
# Current learning rate: [0.0009528893909706795]
#
# [Epoch 8/50]
# Epoch 8: train_loss=0.3178, val_loss=0.3295, miou=0.1143, dice=0.1892, precision=0.5038, recall=0.1476, acc=0.1476
# Current learning rate: [0.0009387718066217122]
# Model saved to result_foodseg103/resnet50_8x_cosine_accu_bgmix05_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 9/50]
# Epoch 9: train_loss=0.3477, val_loss=0.3215, miou=0.0978, dice=0.1625, precision=0.5235, recall=0.1140, acc=0.1140
# Current learning rate: [0.0009229423231234972]
#
# [Epoch 10/50]
# Epoch 10: train_loss=0.3149, val_loss=0.3222, miou=0.2421, dice=0.3718, precision=0.4689, recall=0.3468, acc=0.3468
# Current learning rate: [0.0009054634122155987]
# Model saved to result_foodseg103/resnet50_8x_cosine_accu_bgmix05_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 11/50]
# Epoch 11: train_loss=0.3026, val_loss=0.3247, miou=0.1252, dice=0.2042, precision=0.4780, recall=0.1583, acc=0.1583
# Current learning rate: [0.0008864040551740153]
#
# [Epoch 12/50]
# Epoch 12: train_loss=0.3143, val_loss=0.3224, miou=0.1631, dice=0.2492, precision=0.4772, recall=0.2096, acc=0.2096
# Current learning rate: [0.0008658394705735984]
#
# [Epoch 13/50]
# Epoch 13: train_loss=0.3235, val_loss=0.3066, miou=0.1859, dice=0.2783, precision=0.4903, recall=0.2444, acc=0.2444
# Current learning rate: [0.0008438508174347006]
#
# [Epoch 14/50]
# Epoch 14: train_loss=0.2955, val_loss=0.3109, miou=0.2813, dice=0.4088, precision=0.4854, recall=0.4174, acc=0.4174
# Current learning rate: [0.000820524874925601]
# Model saved to result_foodseg103/resnet50_8x_cosine_accu_bgmix05_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 15/50]
# Epoch 15: train_loss=0.3108, val_loss=0.3066, miou=0.2917, dice=0.4247, precision=0.4722, recall=0.4547, acc=0.4547
# Current learning rate: [0.000795953699884774]
# Model saved to result_foodseg103/resnet50_8x_cosine_accu_bgmix05_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 16/50]
# Epoch 16: train_loss=0.3083, val_loss=0.3223, miou=0.3358, dice=0.4746, precision=0.4316, recall=0.6072, acc=0.6072
# Current learning rate: [0.000770234263514603]
# Model saved to result_foodseg103/resnet50_8x_cosine_accu_bgmix05_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 17/50]
# Epoch 17: train_loss=0.3161, val_loss=0.3034, miou=0.2155, dice=0.3216, precision=0.4773, recall=0.3090, acc=0.3090
# Current learning rate: [0.0007434680686803488]
#
# [Epoch 18/50]
# Epoch 18: train_loss=0.3366, val_loss=0.3004, miou=0.2201, dice=0.3278, precision=0.5041, recall=0.2875, acc=0.2875
# Current learning rate: [0.0007157607493247108]
#
# [Epoch 19/50]
# Epoch 19: train_loss=0.2834, val_loss=0.3130, miou=0.2624, dice=0.3893, precision=0.4817, recall=0.3914, acc=0.3914
# Current learning rate: [0.0006872216535789154]
#
# [Epoch 20/50]
# Epoch 20: train_loss=0.2982, val_loss=0.3031, miou=0.3184, dice=0.4528, precision=0.4717, recall=0.5122, acc=0.5122
# Current learning rate: [0.0006579634122155987]
#
# [Epoch 21/50]
# Epoch 21: train_loss=0.3013, val_loss=0.2952, miou=0.1913, dice=0.2926, precision=0.5070, recall=0.2388, acc=0.2388
# Current learning rate: [0.0006281014941466028]
#
# [Epoch 22/50]
# Epoch 22: train_loss=0.2981, val_loss=0.3134, miou=0.3373, dice=0.4770, precision=0.4548, recall=0.5709, acc=0.5709
# Current learning rate: [0.0005977537507199335]
# Model saved to result_foodseg103/resnet50_8x_cosine_accu_bgmix05_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 23/50]
# Epoch 23: train_loss=0.2999, val_loss=0.3075, miou=0.1877, dice=0.2859, precision=0.4829, recall=0.2359, acc=0.2359
# Current learning rate: [0.0005670399506143305]
#
# [Epoch 24/50]
# Epoch 24: train_loss=0.2778, val_loss=0.2907, miou=0.2778, dice=0.4013, precision=0.5099, recall=0.3916, acc=0.3916
# Current learning rate: [0.0005360813071670099]
#
# [Epoch 25/50]
# Epoch 25: train_loss=0.2735, val_loss=0.2836, miou=0.3299, dice=0.4643, precision=0.4999, recall=0.4967, acc=0.4967
# Current learning rate: [0.0005049999999999998]
#
# [Epoch 26/50]
# Epoch 26: train_loss=0.3170, val_loss=0.2950, miou=0.2371, dice=0.3506, precision=0.4699, recall=0.3203, acc=0.3203
# Current learning rate: [0.0004739186928329897]
#
# [Epoch 27/50]
# Epoch 27: train_loss=0.2786, val_loss=0.2936, miou=0.2473, dice=0.3645, precision=0.5028, recall=0.3462, acc=0.3462
# Current learning rate: [0.0004429600493856692]
#
# [Epoch 28/50]
# Epoch 28: train_loss=0.2925, val_loss=0.2966, miou=0.3258, dice=0.4609, precision=0.4753, recall=0.5183, acc=0.5183
# Current learning rate: [0.0004122462492800661]
#
# [Epoch 29/50]
# Epoch 29: train_loss=0.2974, val_loss=0.2943, miou=0.2877, dice=0.4174, precision=0.4991, recall=0.4178, acc=0.4178
# Current learning rate: [0.0003818985058533967]
#
# [Epoch 30/50]
# Epoch 30: train_loss=0.2849, val_loss=0.2931, miou=0.2729, dice=0.3982, precision=0.4946, recall=0.3972, acc=0.3972
# Current learning rate: [0.00035203658778440103]
#
# [Epoch 31/50]
# Epoch 31: train_loss=0.3042, val_loss=0.2962, miou=0.3480, dice=0.4866, precision=0.4626, recall=0.5757, acc=0.5757
# Current learning rate: [0.00032277834642108444]
# Model saved to result_foodseg103/resnet50_8x_cosine_accu_bgmix05_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 32/50]
# Epoch 32: train_loss=0.2937, val_loss=0.2784, miou=0.3343, dice=0.4697, precision=0.4809, recall=0.5072, acc=0.5072
# Current learning rate: [0.0002942392506752889]
#
# [Epoch 33/50]
# Epoch 33: train_loss=0.2739, val_loss=0.2852, miou=0.3311, dice=0.4675, precision=0.4782, recall=0.5043, acc=0.5043
# Current learning rate: [0.00026653193131965077]
#
# [Epoch 34/50]
# Epoch 34: train_loss=0.2760, val_loss=0.2843, miou=0.3432, dice=0.4798, precision=0.4806, recall=0.5318, acc=0.5318
# Current learning rate: [0.00023976573648539642]
#
# [Epoch 35/50]
# Epoch 35: train_loss=0.2863, val_loss=0.2683, miou=0.2971, dice=0.4226, precision=0.5123, recall=0.4094, acc=0.4094
# Current learning rate: [0.00021404630011522574]
#
# [Epoch 36/50]
# Epoch 36: train_loss=0.2902, val_loss=0.2701, miou=0.3559, dice=0.4890, precision=0.4820, recall=0.5500, acc=0.5500
# Current learning rate: [0.00018947512507439847]
# Model saved to result_foodseg103/resnet50_8x_cosine_accu_bgmix05_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 37/50]
# Epoch 37: train_loss=0.2907, val_loss=0.2676, miou=0.3044, dice=0.4312, precision=0.4929, recall=0.4226, acc=0.4226
# Current learning rate: [0.000166149182565299]
#
# [Epoch 38/50]
# Epoch 38: train_loss=0.2817, val_loss=0.2762, miou=0.3428, dice=0.4796, precision=0.4858, recall=0.5261, acc=0.5261
# Current learning rate: [0.00014416052942640132]
#
# [Epoch 39/50]
# Epoch 39: train_loss=0.2724, val_loss=0.2704, miou=0.3160, dice=0.4485, precision=0.5056, recall=0.4501, acc=0.4501
# Current learning rate: [0.00012359594482598432]
#
# [Epoch 40/50]
# Epoch 40: train_loss=0.2536, val_loss=0.2642, miou=0.3275, dice=0.4597, precision=0.5000, recall=0.4688, acc=0.4688
# Current learning rate: [0.00010453658778440102]
#
# [Epoch 41/50]
# Epoch 41: train_loss=0.2714, val_loss=0.2696, miou=0.3542, dice=0.4893, precision=0.5022, recall=0.5421, acc=0.5421
# Current learning rate: [8.70576768765026e-05]
#
# [Epoch 42/50]
# Epoch 42: train_loss=0.2861, val_loss=0.2660, miou=0.3099, dice=0.4369, precision=0.4922, recall=0.4374, acc=0.4374
# Current learning rate: [7.12281933782875e-05]
#
# [Epoch 43/50]
# Epoch 43: train_loss=0.2721, val_loss=0.2630, miou=0.3371, dice=0.4684, precision=0.4936, recall=0.4890, acc=0.4890
# Current learning rate: [5.71106090293204e-05]
#
# [Epoch 44/50]
# Epoch 44: train_loss=0.2634, val_loss=0.2660, miou=0.3577, dice=0.4933, precision=0.4931, recall=0.5477, acc=0.5477
# Current learning rate: [4.4760639485315563e-05]
# Model saved to result_foodseg103/resnet50_8x_cosine_accu_bgmix05_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 45/50]
# Epoch 45: train_loss=0.2790, val_loss=0.2574, miou=0.3558, dice=0.4862, precision=0.5118, recall=0.5225, acc=0.5225
# Current learning rate: [3.422702443389899e-05]
#
# [Epoch 46/50]
# Epoch 46: train_loss=0.2768, val_loss=0.2605, miou=0.3654, dice=0.4974, precision=0.4979, recall=0.5572, acc=0.5572
# Current learning rate: [2.5551335241327665e-05]
# Model saved to result_foodseg103/resnet50_8x_cosine_accu_bgmix05_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 47/50]
# Epoch 47: train_loss=0.2881, val_loss=0.2618, miou=0.3729, dice=0.5062, precision=0.4953, recall=0.5784, acc=0.5784
# Current learning rate: [1.876781088929908e-05]
# Model saved to result_foodseg103/resnet50_8x_cosine_accu_bgmix05_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 48/50]
# Epoch 48: train_loss=0.2998, val_loss=0.2628, miou=0.3828, dice=0.5172, precision=0.5017, recall=0.5969, acc=0.5969
# Current learning rate: [1.3903222849333505e-05]
# Model saved to result_foodseg103/resnet50_8x_cosine_accu_bgmix05_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 49/50]
# Epoch 49: train_loss=0.2784, val_loss=0.2625, miou=0.3428, dice=0.4745, precision=0.5181, recall=0.4947, acc=0.4947
# Current learning rate: [1.0976769428005579e-05]
#
# [Epoch 50/50]
# Epoch 50: train_loss=0.2662, val_loss=0.2609, miou=0.3541, dice=0.4857, precision=0.5126, recall=0.5203, acc=0.5203
# Current learning rate: [1e-05]
# Model saved to result_foodseg103/resnet50_8x_cosine_accu_bgmix05_scaler1/checkpoint/model_final.pth
# wandb: ⢿ uploading media/images/Val miou Curve_51_dc53183a55ce86e24db9.png 34...
# wandb: ⢿ uploading media/images/Val dice Curve_52_1a3f7d32d7a7860a5465.png 30...
# wandb: ⢿ uploading media/images/Val precision Curve_53_6b2b5990a55e7394cceb.p...
# wandb: ⢿ uploading media/images/Val recall Curve_54_cf4afad17a7fdbee1cf6.png ...
# wandb: ⢿ uploading output.log 10.7KB/10.7KB (0.7s)
# wandb: + 2 more task(s)
# wandb: ⣻ uploading media/images/Val miou Curve_51_dc53183a55ce86e24db9.png 34...
# wandb: ⣻ uploading media/images/Val dice Curve_52_1a3f7d32d7a7860a5465.png 30...
# wandb: ⣻ uploading media/images/Val precision Curve_53_6b2b5990a55e7394cceb.p...
# wandb: ⣻ uploading media/images/Val recall Curve_54_cf4afad17a7fdbee1cf6.png ...
# wandb: ⣻ uploading output.log 10.7KB/10.7KB (0.7s)
# wandb: + 2 more task(s)
# wandb: ⣽ uploading media/images/Val miou Curve_51_dc53183a55ce86e24db9.png 34...
# wandb: ⣽ uploading media/images/Val dice Curve_52_1a3f7d32d7a7860a5465.png 30...
# wandb: ⣽ uploading media/images/Val precision Curve_53_6b2b5990a55e7394cceb.p...
# wandb: ⣽ uploading media/images/Val recall Curve_54_cf4afad17a7fdbee1cf6.png ...
# wandb: ⣽ uploading output.log 10.7KB/10.7KB (0.7s)
# wandb: + 2 more task(s)
# wandb: ⣾ uploading media/images/Val miou Curve_51_dc53183a55ce86e24db9.png 34...
# wandb: ⣾ uploading media/images/Val dice Curve_52_1a3f7d32d7a7860a5465.png 30...
# wandb: ⣾ uploading media/images/Val precision Curve_53_6b2b5990a55e7394cceb.p...
# wandb: ⣾ uploading media/images/Val recall Curve_54_cf4afad17a7fdbee1cf6.png ...
# wandb: ⣾ uploading output.log 10.7KB/10.7KB (0.7s)
# wandb: + 2 more task(s)
# wandb: ⣷ uploading media/images/Val miou Curve_51_dc53183a55ce86e24db9.png 34...
# wandb: ⣷ uploading media/images/Val dice Curve_52_1a3f7d32d7a7860a5465.png 30...
# wandb: ⣷ uploading media/images/Val precision Curve_53_6b2b5990a55e7394cceb.p...
# wandb: ⣷ uploading media/images/Val recall Curve_54_cf4afad17a7fdbee1cf6.png ...
# wandb: ⣷ uploading output.log 10.7KB/10.7KB (0.7s)
# wandb: + 2 more task(s)
# wandb: ⣯ uploading media/images/Val miou Curve_51_dc53183a55ce86e24db9.png 34...
# wandb: ⣯ uploading media/images/Val dice Curve_52_1a3f7d32d7a7860a5465.png 30...
# wandb: ⣯ uploading media/images/Val precision Curve_53_6b2b5990a55e7394cceb.p...
# wandb: ⣯ uploading media/images/Val recall Curve_54_cf4afad17a7fdbee1cf6.png ...
# wandb: ⣯ uploading output.log 10.7KB/10.7KB (0.7s)
# wandb: + 2 more task(s)
# wandb: ⣟ uploading media/images/Val miou Curve_51_dc53183a55ce86e24db9.png 34...
# wandb: ⣟ uploading media/images/Val dice Curve_52_1a3f7d32d7a7860a5465.png 30...
# wandb: ⣟ uploading media/images/Val precision Curve_53_6b2b5990a55e7394cceb.p...
# wandb: ⣟ uploading media/images/Val recall Curve_54_cf4afad17a7fdbee1cf6.png ...
# wandb: ⣟ uploading output.log 10.7KB/10.7KB (0.7s)
# wandb: + 2 more task(s)
# wandb:
# wandb: ⣟ uploading media/images/Val miou Curve_51_dc53183a55ce86e24db9.png 34...
# wandb: ⣟ uploading media/images/Val dice Curve_52_1a3f7d32d7a7860a5465.png 30...
# wandb: ⣟ uploading media/images/Val precision Curve_53_6b2b5990a55e7394cceb.p...
# wandb: ⣟ uploading media/images/Val recall Curve_54_cf4afad17a7fdbee1cf6.png ...
# wandb: ⣟ uploading output.log 10.7KB/10.7KB (0.7s)
# wandb: + 2 more task(s)
# wandb:
# wandb: Run history:
# wandb:    Loss/train █▆▆▆▄▅▄▅▃▄▃▄▄▄▅▃▃▃▃▂▄▂▃▃▂▃▂▂▃▃▂▂▁▂▂▂▂▃▃▂
# wandb:      Loss/val ▇█▆▅▄▆▄▄▄▄▃▄▃▄▃▄▃▃▄▃▃▃▃▃▃▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁
# wandb:       acc/val ▁▁▁▂▂▁▃▂▅▃▄▆▆█▅▆▇▄█▄▇▅▅▇▆▇▇▇▆▇▇▆▆▇▆▇▇██▇
# wandb:      dice/val ▁▁▁▂▃▁▄▃▆▄▅▇▇▇▅▆▇▅▇▅▇▆▆▇▇█▇▇▇▇▇▇█▇▇█████
# wandb:      miou/val ▁▁▁▂▂▁▃▃▅▃▄▆▆▇▅▆▇▄▇▄▇▇▆▆▇▇▇▆█▇▇▇▇▇▇████▇
# wandb: precision/val ▁▃▇█▄█▇▇▇█▇▇▇█▇█▇▇███▇██▇▇▇█▇███████████
# wandb:    recall/val ▁▁▁▂▂▁▃▂▅▃▄▆▆█▅▇▄█▄▆▅▅▇▆▆▇▇▆▇▆▆▆▇▆▇▇▇██▇
# wandb:
# wandb: Run summary:
# wandb:    Loss/train 0.26622
# wandb:      Loss/val 0.26093
# wandb:       acc/val 0.52034
# wandb:      dice/val 0.48569
# wandb:      miou/val 0.35414
# wandb: precision/val 0.51264
# wandb:    recall/val 0.52034
# wandb:
# wandb: 🚀 View run resnet50_8x_cosine_accu_bgmix05_scaler1 at: https://wandb.ai/ltc735983415-newcastle-university/CSC8639_FewShot_FoodSeg103/runs/k97eh69e
# wandb: ⭐️ View project at: https://wandb.ai/ltc735983415-newcastle-university/CSC8639_FewShot_FoodSeg103
# wandb: Synced 5 W&B file(s), 6 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250729_230329-k97eh69e/logs

# %%
# Predict
# FoodSeg103

args = [
    '--split_class_json', '../data/foodseg103/class_split.json',
    '--class2images_mapping_json', '../data/foodseg103/class2images_mapping.json',
    '--img_dir', '../data/foodseg103/rawdata/image',
    '--mask_dir', '../data/foodseg103/rawdata/mask',

    '--model_name', 'resnet50_8x_cosine_accu_bgmix_scaler',  # 选择模型时更改
    '--seed', '42',
    '--beta_mix', '0.5',
    '--alpha_bg', '1',

    '--n_way', '1',
    '--k_shot', '5',
    '--q_query', '5',
    '--pred_episodes', '100',

    '--batch_size', '1',
    '--num_workers', '10',
    '--metric', 'miou', 'dice', 'precision', 'recall', 'acc',

    '--weight_path', 'result_foodseg103/resnet50_8x_cosine_accu_bgmix05_scaler1/checkpoint/model_best.pth',  # 每次更改
    '--use_amp',

    '--save_dir', 'result_foodseg103/resnet50_8x_cosine_accu_bgmix05_scaler1/predict',  # 每次更改，与 wandb 项目名相同
    '--wandb',  # 设置即启用
]

# !python predict_shell.py {' '.join(args)}
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: ltc735983415 (ltc735983415-newcastle-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /content/drive/.shortcut-targets-by-id/1fuvwH2wo3q3zusv_klINh1muke4KOxCQ/Colab_Notebooks/CSC8639/fewshot_foodseg103/wandb/run-20250729_231522-xshj89eh
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run resnet50_8x_cosine_accu_bgmix05_scaler1/predict
# wandb: ⭐️ View project at https://wandb.ai/ltc735983415-newcastle-university/CSC8639_FewShot_FoodSeg103
# wandb: 🚀 View run at https://wandb.ai/ltc735983415-newcastle-university/CSC8639_FewShot_FoodSeg103/runs/xshj89eh
# miou: 0.3808
# dice: 0.5276
# precision: 0.5746
# recall: 0.5590
# acc: 0.5590
#
# Prediction images saved to: result_foodseg103/resnet50_8x_cosine_accu_bgmix05_scaler1/predict
# wandb: ⢿ uploading wandb-summary.json 137.0KB/137.0KB (0.7s)
# wandb: ⣻ uploading wandb-summary.json 137.0KB/137.0KB (0.7s)
# wandb: ⣽ uploading wandb-summary.json 137.0KB/137.0KB (0.7s)
# wandb: ⣾ uploading wandb-summary.json 137.0KB/137.0KB (0.7s)
# wandb: ⣷ uploading wandb-summary.json 137.0KB/137.0KB (0.7s)
# wandb: ⣯ uploading wandb-summary.json 137.0KB/137.0KB (0.7s)
# wandb: ⣟ uploading wandb-summary.json 137.0KB/137.0KB (0.7s)
# wandb: ⡿ uploading wandb-summary.json 137.0KB/137.0KB (0.7s)
# wandb: ⢿ uploading wandb-summary.json 137.0KB/137.0KB (0.7s)
# wandb:
# wandb: ⢿ uploading wandb-summary.json 137.0KB/137.0KB (0.7s)
# wandb:
# wandb: Run summary:
# wandb:       acc 0.55898
# wandb:      dice 0.52764
# wandb:      miou 0.38081
# wandb: precision 0.57458
# wandb:    recall 0.55898
# wandb:
# wandb: 🚀 View run resnet50_8x_cosine_accu_bgmix05_scaler1/predict at: https://wandb.ai/ltc735983415-newcastle-university/CSC8639_FewShot_FoodSeg103/runs/xshj89eh
# wandb: ⭐️ View project at: https://wandb.ai/ltc735983415-newcastle-university/CSC8639_FewShot_FoodSeg103
# wandb: Synced 5 W&B file(s), 500 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250729_231522-xshj89eh/logs
