# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/Colab_Notebooks/CSC8639/fewshot_foodseg103')

# %%
# !pip install segmentation_models_pytorch
# Out:
# Collecting segmentation_models_pytorch
#   Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: huggingface-hub>=0.24 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (0.34.1)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (2.0.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (11.3.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (0.5.3)
# Requirement already satisfied: timm>=0.9 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (1.0.19)
# Requirement already satisfied: torch>=1.8 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (1.1.5)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8->segmentation_models_pytorch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8->segmentation_models_pytorch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.24->segmentation_models_pytorch) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.24->segmentation_models_pytorch) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.24->segmentation_models_pytorch) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.24->segmentation_models_pytorch) (2025.7.14)
# Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 19.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 130.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 80.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 66.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 39.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 12.7 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 111.4 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, segmentation_models_pytorch
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 segmentation_models_pytorch-0.5.0

# %%
# Train
# FoodSeg103

args = [
    '--split_class_json', '../data/foodseg103/class_split.json',
    '--class2images_mapping_json', '../data/foodseg103/class2images_mapping.json',
    '--img_dir', '../data/foodseg103/rawdata/image',
    '--mask_dir', '../data/foodseg103/rawdata/mask',

    '--model_name', 'resnet50_8x_cosine_accu_bgmix_scaler',  # 选择模型时更改
    '--seed', '42',
    '--beta_mix', '0.25',
    '--alpha_bg', '1',

    '--n_way', '1',
    '--k_shot', '5',
    '--q_query', '5',
    '--train_episodes', '100',
    '--val_episodes', '50',

    '--batch_size', '1',
    '--num_workers', '10',
    '--epochs', '50',

    '--optimizer', 'adamw',  # adam/adamw/sgd
    '--scheduler', 'cosine',  # step/cosine/cosine_restart/plateau
    '--learning_rate', '1e-3',
    '--weight_decay', '1e-4',
    '--loss', 'ce',  # ce/dice/focal/combo
    # '--bg_weight', '0.8',  # loss中背景类别权重（已在trainshell中禁用）
    '--metric', 'miou', 'dice', 'precision', 'recall', 'acc',  # 启用的metrics

    '--main_metric', 'miou',  # loss/miou/dice/acc  # 指定监控指标（默认为loss），最佳模型保存策略、plateau学习率下降策略、早停策略共用此指标
    # '--early_stopping_patience', '25',  # 设置早停轮数即启用早停

    # '--weight_path',  # 预训练模型/上次训练模型 路径
    # '--is_resume',  # 断点训练
    '--use_amp',

    '--save_dir', 'result_foodseg103/resnet50_8x_cosine_accu_bgmix025_scaler1',  # 每次更改，与 wandb 项目名相同
    '--wandb'  # 设置即启用
    ]

# !python train_shell.py {' '.join(args)}
# Out:
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: ltc735983415 (ltc735983415-newcastle-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /content/drive/.shortcut-targets-by-id/1fuvwH2wo3q3zusv_klINh1muke4KOxCQ/Colab_Notebooks/CSC8639/fewshot_foodseg103/wandb/run-20250729_220230-6hg4lg3y
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run resnet50_8x_cosine_accu_bgmix025_scaler1
# wandb: ⭐️ View project at https://wandb.ai/ltc735983415-newcastle-university/CSC8639_FewShot_FoodSeg103
# wandb: 🚀 View run at https://wandb.ai/ltc735983415-newcastle-university/CSC8639_FewShot_FoodSeg103/runs/6hg4lg3y
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100% 97.8M/97.8M [00:00<00:00, 233MB/s]
# Start training New Model
# [CONFIG] n_way=1, k_shot=5, q_query=5, train_episodes=100, val_episodes=50
#
#
#
# [Epoch 1/50]
# Epoch 1: train_loss=0.4077, val_loss=0.3902, miou=0.0115, dice=0.0215, precision=0.2823, recall=0.0121, acc=0.0121
# Current learning rate: [0.0009990232305719944]
# Model saved to result_foodseg103/resnet50_8x_cosine_accu_bgmix025_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 2/50]
# Epoch 2: train_loss=0.3684, val_loss=0.3853, miou=0.0058, dice=0.0113, precision=0.2990, recall=0.0060, acc=0.0060
# Current learning rate: [0.0009960967771506664]
#
# [Epoch 3/50]
# Epoch 3: train_loss=0.3589, val_loss=0.3635, miou=0.0094, dice=0.0173, precision=0.2856, recall=0.0098, acc=0.0098
# Current learning rate: [0.0009912321891107007]
#
# [Epoch 4/50]
# Epoch 4: train_loss=0.3704, val_loss=0.3572, miou=0.0351, dice=0.0636, precision=0.2495, recall=0.0405, acc=0.0405
# Current learning rate: [0.0009844486647586721]
# Model saved to result_foodseg103/resnet50_8x_cosine_accu_bgmix025_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 5/50]
# Epoch 5: train_loss=0.3217, val_loss=0.3384, miou=0.0072, dice=0.0136, precision=0.3113, recall=0.0072, acc=0.0072
# Current learning rate: [0.0009757729755661009]
#
# [Epoch 6/50]
# Epoch 6: train_loss=0.3291, val_loss=0.3666, miou=0.0417, dice=0.0716, precision=0.4629, recall=0.0481, acc=0.0481
# Current learning rate: [0.0009652393605146842]
# Model saved to result_foodseg103/resnet50_8x_cosine_accu_bgmix025_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 7/50]
# Epoch 7: train_loss=0.3570, val_loss=0.3502, miou=0.0011, dice=0.0021, precision=0.1208, recall=0.0011, acc=0.0011
# Current learning rate: [0.0009528893909706795]
#
# [Epoch 8/50]
# Epoch 8: train_loss=0.3224, val_loss=0.3401, miou=0.1165, dice=0.1928, precision=0.4794, recall=0.1591, acc=0.1591
# Current learning rate: [0.0009387718066217122]
# Model saved to result_foodseg103/resnet50_8x_cosine_accu_bgmix025_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 9/50]
# Epoch 9: train_loss=0.3569, val_loss=0.3346, miou=0.0690, dice=0.1201, precision=0.4772, recall=0.0773, acc=0.0773
# Current learning rate: [0.0009229423231234972]
#
# [Epoch 10/50]
# Epoch 10: train_loss=0.3205, val_loss=0.3331, miou=0.1858, dice=0.3019, precision=0.4480, recall=0.2478, acc=0.2478
# Current learning rate: [0.0009054634122155987]
# Model saved to result_foodseg103/resnet50_8x_cosine_accu_bgmix025_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 11/50]
# Epoch 11: train_loss=0.3080, val_loss=0.3296, miou=0.1144, dice=0.1878, precision=0.4822, recall=0.1487, acc=0.1487
# Current learning rate: [0.0008864040551740153]
#
# [Epoch 12/50]
# Epoch 12: train_loss=0.3198, val_loss=0.3160, miou=0.1141, dice=0.1878, precision=0.4753, recall=0.1389, acc=0.1389
# Current learning rate: [0.0008658394705735984]
#
# [Epoch 13/50]
# Epoch 13: train_loss=0.3304, val_loss=0.3108, miou=0.0896, dice=0.1498, precision=0.5230, recall=0.1090, acc=0.1090
# Current learning rate: [0.0008438508174347006]
#
# [Epoch 14/50]
# Epoch 14: train_loss=0.3024, val_loss=0.3074, miou=0.2232, dice=0.3396, precision=0.4793, recall=0.3111, acc=0.3111
# Current learning rate: [0.000820524874925601]
# Model saved to result_foodseg103/resnet50_8x_cosine_accu_bgmix025_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 15/50]
# Epoch 15: train_loss=0.3196, val_loss=0.3149, miou=0.2355, dice=0.3602, precision=0.4635, recall=0.3369, acc=0.3369
# Current learning rate: [0.000795953699884774]
# Model saved to result_foodseg103/resnet50_8x_cosine_accu_bgmix025_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 16/50]
# Epoch 16: train_loss=0.3100, val_loss=0.3256, miou=0.3145, dice=0.4563, precision=0.4399, recall=0.5436, acc=0.5436
# Current learning rate: [0.000770234263514603]
# Model saved to result_foodseg103/resnet50_8x_cosine_accu_bgmix025_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 17/50]
# Epoch 17: train_loss=0.3185, val_loss=0.3269, miou=0.1585, dice=0.2404, precision=0.4987, recall=0.2240, acc=0.2240
# Current learning rate: [0.0007434680686803488]
#
# [Epoch 18/50]
# Epoch 18: train_loss=0.3391, val_loss=0.3134, miou=0.1978, dice=0.2992, precision=0.5113, recall=0.2581, acc=0.2581
# Current learning rate: [0.0007157607493247108]
#
# [Epoch 19/50]
# Epoch 19: train_loss=0.2878, val_loss=0.3077, miou=0.2384, dice=0.3540, precision=0.5076, recall=0.3463, acc=0.3463
# Current learning rate: [0.0006872216535789154]
#
# [Epoch 20/50]
# Epoch 20: train_loss=0.3022, val_loss=0.3079, miou=0.2926, dice=0.4214, precision=0.4569, recall=0.4605, acc=0.4605
# Current learning rate: [0.0006579634122155987]
#
# [Epoch 21/50]
# Epoch 21: train_loss=0.3084, val_loss=0.2996, miou=0.2070, dice=0.3099, precision=0.5192, recall=0.2683, acc=0.2683
# Current learning rate: [0.0006281014941466028]
#
# [Epoch 22/50]
# Epoch 22: train_loss=0.3037, val_loss=0.3323, miou=0.3238, dice=0.4642, precision=0.4285, recall=0.5870, acc=0.5870
# Current learning rate: [0.0005977537507199335]
# Model saved to result_foodseg103/resnet50_8x_cosine_accu_bgmix025_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 23/50]
# Epoch 23: train_loss=0.3051, val_loss=0.3188, miou=0.1623, dice=0.2507, precision=0.5132, recall=0.1963, acc=0.1963
# Current learning rate: [0.0005670399506143305]
#
# [Epoch 24/50]
# Epoch 24: train_loss=0.2786, val_loss=0.2974, miou=0.2432, dice=0.3568, precision=0.4896, recall=0.3344, acc=0.3344
# Current learning rate: [0.0005360813071670099]
#
# [Epoch 25/50]
# Epoch 25: train_loss=0.2752, val_loss=0.2950, miou=0.3100, dice=0.4441, precision=0.4828, recall=0.4751, acc=0.4751
# Current learning rate: [0.0005049999999999998]
#
# [Epoch 26/50]
# Epoch 26: train_loss=0.3184, val_loss=0.3004, miou=0.2426, dice=0.3578, precision=0.4705, recall=0.3327, acc=0.3327
# Current learning rate: [0.0004739186928329897]
#
# [Epoch 27/50]
# Epoch 27: train_loss=0.2826, val_loss=0.2862, miou=0.2804, dice=0.4067, precision=0.4808, recall=0.4072, acc=0.4072
# Current learning rate: [0.0004429600493856692]
#
# [Epoch 28/50]
# Epoch 28: train_loss=0.2951, val_loss=0.3072, miou=0.3075, dice=0.4405, precision=0.4507, recall=0.5017, acc=0.5017
# Current learning rate: [0.0004122462492800661]
#
# [Epoch 29/50]
# Epoch 29: train_loss=0.3020, val_loss=0.2999, miou=0.2836, dice=0.4128, precision=0.4940, recall=0.4142, acc=0.4142
# Current learning rate: [0.0003818985058533967]
#
# [Epoch 30/50]
# Epoch 30: train_loss=0.2889, val_loss=0.2940, miou=0.2801, dice=0.4070, precision=0.5160, recall=0.4078, acc=0.4078
# Current learning rate: [0.00035203658778440103]
#
# [Epoch 31/50]
# Epoch 31: train_loss=0.3095, val_loss=0.2997, miou=0.3349, dice=0.4732, precision=0.4592, recall=0.5505, acc=0.5505
# Current learning rate: [0.00032277834642108444]
# Model saved to result_foodseg103/resnet50_8x_cosine_accu_bgmix025_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 32/50]
# Epoch 32: train_loss=0.2961, val_loss=0.2816, miou=0.3320, dice=0.4694, precision=0.5058, recall=0.4962, acc=0.4962
# Current learning rate: [0.0002942392506752889]
#
# [Epoch 33/50]
# Epoch 33: train_loss=0.2785, val_loss=0.2923, miou=0.3217, dice=0.4566, precision=0.4768, recall=0.4839, acc=0.4839
# Current learning rate: [0.00026653193131965077]
#
# [Epoch 34/50]
# Epoch 34: train_loss=0.2824, val_loss=0.2874, miou=0.3254, dice=0.4602, precision=0.4925, recall=0.4912, acc=0.4912
# Current learning rate: [0.00023976573648539642]
#
# [Epoch 35/50]
# Epoch 35: train_loss=0.2921, val_loss=0.2779, miou=0.2909, dice=0.4151, precision=0.5173, recall=0.4018, acc=0.4018
# Current learning rate: [0.00021404630011522574]
#
# [Epoch 36/50]
# Epoch 36: train_loss=0.2958, val_loss=0.2769, miou=0.3573, dice=0.4941, precision=0.4941, recall=0.5448, acc=0.5448
# Current learning rate: [0.00018947512507439847]
# Model saved to result_foodseg103/resnet50_8x_cosine_accu_bgmix025_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 37/50]
# Epoch 37: train_loss=0.2972, val_loss=0.2759, miou=0.3032, dice=0.4331, precision=0.5015, recall=0.4176, acc=0.4176
# Current learning rate: [0.000166149182565299]
#
# [Epoch 38/50]
# Epoch 38: train_loss=0.2863, val_loss=0.2818, miou=0.3452, dice=0.4814, precision=0.4912, recall=0.5231, acc=0.5231
# Current learning rate: [0.00014416052942640132]
#
# [Epoch 39/50]
# Epoch 39: train_loss=0.2781, val_loss=0.2787, miou=0.3055, dice=0.4382, precision=0.5074, recall=0.4299, acc=0.4299
# Current learning rate: [0.00012359594482598432]
#
# [Epoch 40/50]
# Epoch 40: train_loss=0.2578, val_loss=0.2751, miou=0.3179, dice=0.4515, precision=0.5031, recall=0.4532, acc=0.4532
# Current learning rate: [0.00010453658778440102]
#
# [Epoch 41/50]
# Epoch 41: train_loss=0.2782, val_loss=0.2779, miou=0.3478, dice=0.4855, precision=0.5009, recall=0.5288, acc=0.5288
# Current learning rate: [8.70576768765026e-05]
#
# [Epoch 42/50]
# Epoch 42: train_loss=0.2908, val_loss=0.2728, miou=0.2987, dice=0.4258, precision=0.5018, recall=0.4146, acc=0.4146
# Current learning rate: [7.12281933782875e-05]
#
# [Epoch 43/50]
# Epoch 43: train_loss=0.2770, val_loss=0.2690, miou=0.3273, dice=0.4593, precision=0.5027, recall=0.4682, acc=0.4682
# Current learning rate: [5.71106090293204e-05]
#
# [Epoch 44/50]
# Epoch 44: train_loss=0.2692, val_loss=0.2708, miou=0.3522, dice=0.4897, precision=0.5010, recall=0.5317, acc=0.5317
# Current learning rate: [4.4760639485315563e-05]
#
# [Epoch 45/50]
# Epoch 45: train_loss=0.2857, val_loss=0.2646, miou=0.3464, dice=0.4813, precision=0.5117, recall=0.5012, acc=0.5012
# Current learning rate: [3.422702443389899e-05]
#
# [Epoch 46/50]
# Epoch 46: train_loss=0.2826, val_loss=0.2666, miou=0.3529, dice=0.4888, precision=0.5073, recall=0.5258, acc=0.5258
# Current learning rate: [2.5551335241327665e-05]
#
# [Epoch 47/50]
# Epoch 47: train_loss=0.2918, val_loss=0.2698, miou=0.3672, dice=0.5047, precision=0.5003, recall=0.5666, acc=0.5666
# Current learning rate: [1.876781088929908e-05]
# Model saved to result_foodseg103/resnet50_8x_cosine_accu_bgmix025_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 48/50]
# Epoch 48: train_loss=0.3061, val_loss=0.2698, miou=0.3765, dice=0.5151, precision=0.5043, recall=0.5857, acc=0.5857
# Current learning rate: [1.3903222849333505e-05]
# Model saved to result_foodseg103/resnet50_8x_cosine_accu_bgmix025_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 49/50]
# Epoch 49: train_loss=0.2839, val_loss=0.2699, miou=0.3314, dice=0.4644, precision=0.5165, recall=0.4776, acc=0.4776
# Current learning rate: [1.0976769428005579e-05]
#
# [Epoch 50/50]
# Epoch 50: train_loss=0.2717, val_loss=0.2678, miou=0.3411, dice=0.4749, precision=0.5147, recall=0.4956, acc=0.4956
# Current learning rate: [1e-05]
# Model saved to result_foodseg103/resnet50_8x_cosine_accu_bgmix025_scaler1/checkpoint/model_final.pth
# wandb: ⢿ uploading media/images/Val miou Curve_51_07a3ccad8abd813a1812.png 33...
# wandb: ⢿ uploading media/images/Val dice Curve_52_5e4fad49aeb1443f15a9.png 31...
# wandb: ⢿ uploading media/images/Val precision Curve_53_8d1f200372027c7c983e.p...
# wandb: ⢿ uploading media/images/Val recall Curve_54_4f33f8c3046afdcb29f1.png ...
# wandb: ⢿ uploading wandb-summary.json 1.7KB/1.7KB (0.7s)
# wandb: + 2 more task(s)
# wandb: ⣻ uploading media/images/Val miou Curve_51_07a3ccad8abd813a1812.png 33...
# wandb: ⣻ uploading media/images/Val dice Curve_52_5e4fad49aeb1443f15a9.png 31...
# wandb: ⣻ uploading media/images/Val precision Curve_53_8d1f200372027c7c983e.p...
# wandb: ⣻ uploading media/images/Val recall Curve_54_4f33f8c3046afdcb29f1.png ...
# wandb: ⣻ uploading wandb-summary.json 1.7KB/1.7KB (0.7s)
# wandb: + 2 more task(s)
# wandb: ⣽ uploading media/images/Val miou Curve_51_07a3ccad8abd813a1812.png 33...
# wandb: ⣽ uploading media/images/Val dice Curve_52_5e4fad49aeb1443f15a9.png 31...
# wandb: ⣽ uploading media/images/Val precision Curve_53_8d1f200372027c7c983e.p...
# wandb: ⣽ uploading media/images/Val recall Curve_54_4f33f8c3046afdcb29f1.png ...
# wandb: ⣽ uploading wandb-summary.json 1.7KB/1.7KB (0.7s)
# wandb: + 2 more task(s)
# wandb: ⣾ uploading media/images/Val miou Curve_51_07a3ccad8abd813a1812.png 33...
# wandb: ⣾ uploading media/images/Val dice Curve_52_5e4fad49aeb1443f15a9.png 31...
# wandb: ⣾ uploading media/images/Val precision Curve_53_8d1f200372027c7c983e.p...
# wandb: ⣾ uploading media/images/Val recall Curve_54_4f33f8c3046afdcb29f1.png ...
# wandb: ⣾ uploading wandb-summary.json 1.7KB/1.7KB (0.7s)
# wandb: + 2 more task(s)
# wandb: ⣷ uploading media/images/Val miou Curve_51_07a3ccad8abd813a1812.png 33...
# wandb: ⣷ uploading media/images/Val dice Curve_52_5e4fad49aeb1443f15a9.png 31...
# wandb: ⣷ uploading media/images/Val precision Curve_53_8d1f200372027c7c983e.p...
# wandb: ⣷ uploading media/images/Val recall Curve_54_4f33f8c3046afdcb29f1.png ...
# wandb: ⣷ uploading wandb-summary.json 1.7KB/1.7KB (0.7s)
# wandb: + 2 more task(s)
# wandb: ⣯ uploading media/images/Val miou Curve_51_07a3ccad8abd813a1812.png 33...
# wandb: ⣯ uploading media/images/Val dice Curve_52_5e4fad49aeb1443f15a9.png 31...
# wandb: ⣯ uploading media/images/Val precision Curve_53_8d1f200372027c7c983e.p...
# wandb: ⣯ uploading media/images/Val recall Curve_54_4f33f8c3046afdcb29f1.png ...
# wandb: ⣯ uploading wandb-summary.json 1.7KB/1.7KB (0.7s)
# wandb: + 2 more task(s)
# wandb: ⣟ uploading media/images/Val miou Curve_51_07a3ccad8abd813a1812.png 33...
# wandb: ⣟ uploading media/images/Val dice Curve_52_5e4fad49aeb1443f15a9.png 31...
# wandb: ⣟ uploading media/images/Val precision Curve_53_8d1f200372027c7c983e.p...
# wandb: ⣟ uploading media/images/Val recall Curve_54_4f33f8c3046afdcb29f1.png ...
# wandb: ⣟ uploading wandb-summary.json 1.7KB/1.7KB (0.7s)
# wandb: + 2 more task(s)
# wandb:
# wandb: ⣟ uploading media/images/Val miou Curve_51_07a3ccad8abd813a1812.png 33...
# wandb: ⣟ uploading media/images/Val dice Curve_52_5e4fad49aeb1443f15a9.png 31...
# wandb: ⣟ uploading media/images/Val precision Curve_53_8d1f200372027c7c983e.p...
# wandb: ⣟ uploading media/images/Val recall Curve_54_4f33f8c3046afdcb29f1.png ...
# wandb: ⣟ uploading wandb-summary.json 1.7KB/1.7KB (0.7s)
# wandb: + 2 more task(s)
# wandb:
# wandb: Run history:
# wandb:    Loss/train █▆▆▆▄▆▄▆▄▃▄▃▄▃▄▂▃▃▃▃▂▄▂▃▃▃▃▂▂▃▃▂▂▁▂▂▂▂▃▂
# wandb:      Loss/val █▇▆▅▇▅▅▅▄▄▄▄▄▄▃▃▅▄▃▃▂▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁
# wandb:       acc/val ▁▁▁▁▁▃▄▃▃▂▅▇▄▄▅▄█▃▅▇▆▇▆▆█▇▇▆▇▆▆▆▇▆▇▇▇██▇
# wandb:      dice/val ▁▁▁▂▁▁▄▃▄▄▆▆▄▅▆▅▇▄▆▇▇▇▇▇▇▇▇▇█▇▇▇█▇▇████▇
# wandb:      miou/val ▁▁▁▂▁▁▂▄▃▃▅▅▇▄▅▆▅▇▄▆▆▇▆▆▇▇▇▆█▇▇▇▇▇▇▇███▇
# wandb: precision/val ▄▄▄▃▄▁▇▇▇▇█▇▇▇██▇█▆█▇▇▇▇▇█▇▇█▇▇█████████
# wandb:    recall/val ▁▁▁▁▁▁▃▂▄▃▂▅▅▇▄▅▆▄█▃▇▅▆▇▆▇▇▇▆▆▆▆▇▆▇▇▇██▇
# wandb:
# wandb: Run summary:
# wandb:    Loss/train 0.27171
# wandb:      Loss/val 0.26778
# wandb:       acc/val 0.49563
# wandb:      dice/val 0.47486
# wandb:      miou/val 0.34107
# wandb: precision/val 0.51465
# wandb:    recall/val 0.49563
# wandb:
# wandb: 🚀 View run resnet50_8x_cosine_accu_bgmix025_scaler1 at: https://wandb.ai/ltc735983415-newcastle-university/CSC8639_FewShot_FoodSeg103/runs/6hg4lg3y
# wandb: ⭐️ View project at: https://wandb.ai/ltc735983415-newcastle-university/CSC8639_FewShot_FoodSeg103
# wandb: Synced 5 W&B file(s), 6 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250729_220230-6hg4lg3y/logs

# %%
# Predict
# FoodSeg103

args = [
    '--split_class_json', '../data/foodseg103/class_split.json',
    '--class2images_mapping_json', '../data/foodseg103/class2images_mapping.json',
    '--img_dir', '../data/foodseg103/rawdata/image',
    '--mask_dir', '../data/foodseg103/rawdata/mask',

    '--model_name', 'resnet50_8x_cosine_accu_bgmix_scaler',  # 选择模型时更改
    '--seed', '42',
    '--beta_mix', '0.25',
    '--alpha_bg', '1',

    '--n_way', '1',
    '--k_shot', '5',
    '--q_query', '5',
    '--pred_episodes', '100',

    '--batch_size', '1',
    '--num_workers', '10',
    '--metric', 'miou', 'dice', 'precision', 'recall', 'acc',

    '--weight_path', 'result_foodseg103/resnet50_8x_cosine_accu_bgmix025_scaler1/checkpoint/model_best.pth',  # 每次更改
    '--use_amp',

    '--save_dir', 'result_foodseg103/resnet50_8x_cosine_accu_bgmix025_scaler1/predict',  # 每次更改，与 wandb 项目名相同
    '--wandb',  # 设置即启用
]

# !python predict_shell.py {' '.join(args)}
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: ltc735983415 (ltc735983415-newcastle-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ creating run (0.7s)
# wandb: ⣻ creating run (0.7s)
# wandb: ⣽ creating run (0.7s)
# wandb: ⣾ creating run (0.7s)
# wandb: ⣷ creating run (1.2s)
# wandb: ⣯ creating run (1.2s)
# wandb: ⣟ creating run (1.2s)
# wandb: ⡿ creating run (1.2s)
# wandb: ⢿ creating run (1.2s)
# wandb: ⣻ creating run (1.7s)
# wandb: ⣽ creating run (1.7s)
# wandb: ⣾ creating run (1.7s)
# wandb: ⣷ creating run (1.7s)
# wandb: ⣯ creating run (1.7s)
# wandb: ⣟ creating run (2.2s)
# wandb: ⡿ creating run (2.2s)
# wandb: ⢿ creating run (2.2s)
# wandb: ⣻ creating run (2.2s)
# wandb: ⣽ creating run (2.2s)
# wandb: ⣾ creating run (2.7s)
# wandb: ⣷ creating run (2.7s)
# wandb: ⣯ creating run (2.7s)
# wandb: ⣟ creating run (2.7s)
# wandb: ⡿ creating run (2.7s)
# wandb: ⢿ creating run (3.2s)
# wandb: ⣻ creating run (3.2s)
# wandb: ⣽ creating run (3.2s)
# wandb: ⣾ creating run (3.2s)
# wandb: ⣷ creating run (3.2s)
# wandb: ⣯ creating run (3.7s)
# wandb: ⣟ creating run (3.7s)
# wandb: ⡿ creating run (3.7s)
# wandb: ⢿ creating run (3.7s)
# wandb: ⣻ creating run (3.7s)
# wandb: ⣽ creating run (4.2s)
# wandb: ⣾ creating run (4.2s)
# wandb: ⣷ creating run (4.2s)
# wandb: ⣯ creating run (4.2s)
# wandb: ⣟ creating run (4.2s)
# wandb: ⡿ creating run (4.7s)
# wandb: ⢿ creating run (4.7s)
# wandb: ⣻ creating run (4.7s)
# wandb: ⣽ creating run (4.7s)
# wandb: ⣾ creating run (4.7s)
# wandb: ⣷ creating run (5.2s)
# wandb: ⣯ creating run (5.2s)
# wandb: ⣟ creating run (5.2s)
# wandb: ⡿ creating run (5.2s)
# wandb: ⢿ creating run (5.2s)
# wandb: ⣻ creating run (5.7s)
# wandb: ⣽ creating run (5.7s)
# wandb: ⣾ creating run (5.7s)
# wandb: ⣷ creating run (5.7s)
# wandb: ⣯ creating run (5.7s)
# wandb: ⣟ creating run (6.2s)
# wandb: ⡿ creating run (6.2s)
# wandb: ⢿ creating run (6.2s)
# wandb: ⣻ creating run (6.2s)
# wandb: ⣽ creating run (6.2s)
# wandb: ⣾ creating run (6.7s)
# wandb: ⣷ creating run (6.7s)
# wandb: ⣯ creating run (6.7s)
# wandb: ⣟ creating run (6.7s)
# wandb: ⡿ creating run (6.7s)
# wandb: ⢿ creating run (7.2s)
# wandb: ⣻ creating run (7.2s)
# wandb: ⣽ creating run (7.2s)
# wandb: ⣾ creating run (7.2s)
# wandb: ⣷ creating run (7.2s)
# wandb: ⣯ creating run (7.7s)
# wandb: ⣟ creating run (7.7s)
# wandb: ⡿ creating run (7.7s)
# wandb: ⢿ creating run (7.7s)
# wandb: ⣻ creating run (7.7s)
# wandb: ⣽ creating run (8.2s)
# wandb: ⣾ creating run (8.2s)
# wandb: ⣷ creating run (8.2s)
# wandb: ⣯ creating run (8.2s)
# wandb: ⣟ creating run (8.2s)
# wandb: ⡿ creating run (8.7s)
# wandb: ⢿ creating run (8.7s)
# wandb: ⣻ creating run (8.7s)
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /content/drive/.shortcut-targets-by-id/1fuvwH2wo3q3zusv_klINh1muke4KOxCQ/Colab_Notebooks/CSC8639/fewshot_foodseg103/wandb/run-20250729_223739-r1xrbily
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run resnet50_8x_cosine_accu_bgmix025_scaler1/predict
# wandb: ⭐️ View project at https://wandb.ai/ltc735983415-newcastle-university/CSC8639_FewShot_FoodSeg103
# wandb: 🚀 View run at https://wandb.ai/ltc735983415-newcastle-university/CSC8639_FewShot_FoodSeg103/runs/r1xrbily
# miou: 0.3830
# dice: 0.5308
# precision: 0.5687
# recall: 0.5621
# acc: 0.5621
#
# Prediction images saved to: result_foodseg103/resnet50_8x_cosine_accu_bgmix025_scaler1/predict
# wandb: ⢿ uploading media/images/Pred_Img/Group_Img/486_group_486.png_485_cbf4...
# wandb: ⢿ uploading media/images/Pred_Img/Group_Img/493_group_493.png_492_3e1b...
# wandb: ⢿ uploading media/images/Pred_Img/Group_Img/497_group_497.png_496_575d...
# wandb: ⢿ uploading media/images/Pred_Img/Group_Img/498_group_498.png_497_c81b...
# wandb: ⢿ uploading media/images/Pred_Img/Group_Img/488_group_488.png_487_3c5d...
# wandb: + 12 more task(s)
# wandb: ⣻ uploading media/images/Pred_Img/Group_Img/486_group_486.png_485_cbf4...
# wandb: ⣻ uploading media/images/Pred_Img/Group_Img/493_group_493.png_492_3e1b...
# wandb: ⣻ uploading media/images/Pred_Img/Group_Img/497_group_497.png_496_575d...
# wandb: ⣻ uploading media/images/Pred_Img/Group_Img/498_group_498.png_497_c81b...
# wandb: ⣻ uploading media/images/Pred_Img/Group_Img/488_group_488.png_487_3c5d...
# wandb: + 12 more task(s)
# wandb: ⣽ uploading media/images/Pred_Img/Group_Img/486_group_486.png_485_cbf4...
# wandb: ⣽ uploading media/images/Pred_Img/Group_Img/493_group_493.png_492_3e1b...
# wandb: ⣽ uploading media/images/Pred_Img/Group_Img/497_group_497.png_496_575d...
# wandb: ⣽ uploading media/images/Pred_Img/Group_Img/498_group_498.png_497_c81b...
# wandb: ⣽ uploading media/images/Pred_Img/Group_Img/488_group_488.png_487_3c5d...
# wandb: + 12 more task(s)
# wandb: ⣾ uploading media/images/Pred_Img/Group_Img/486_group_486.png_485_cbf4...
# wandb: ⣾ uploading media/images/Pred_Img/Group_Img/493_group_493.png_492_3e1b...
# wandb: ⣾ uploading media/images/Pred_Img/Group_Img/497_group_497.png_496_575d...
# wandb: ⣾ uploading media/images/Pred_Img/Group_Img/498_group_498.png_497_c81b...
# wandb: ⣾ uploading media/images/Pred_Img/Group_Img/488_group_488.png_487_3c5d...
# wandb: + 12 more task(s)
# wandb: ⣷ uploading media/images/Pred_Img/Group_Img/486_group_486.png_485_cbf4...
# wandb: ⣷ uploading media/images/Pred_Img/Group_Img/493_group_493.png_492_3e1b...
# wandb: ⣷ uploading media/images/Pred_Img/Group_Img/497_group_497.png_496_575d...
# wandb: ⣷ uploading media/images/Pred_Img/Group_Img/498_group_498.png_497_c81b...
# wandb: ⣷ uploading media/images/Pred_Img/Group_Img/488_group_488.png_487_3c5d...
# wandb: + 12 more task(s)
# wandb: ⣯ uploading media/images/Pred_Img/Group_Img/486_group_486.png_485_cbf4...
# wandb: ⣯ uploading media/images/Pred_Img/Group_Img/493_group_493.png_492_3e1b...
# wandb: ⣯ uploading media/images/Pred_Img/Group_Img/497_group_497.png_496_575d...
# wandb: ⣯ uploading media/images/Pred_Img/Group_Img/498_group_498.png_497_c81b...
# wandb: ⣯ uploading media/images/Pred_Img/Group_Img/488_group_488.png_487_3c5d...
# wandb: + 12 more task(s)
# wandb:
# wandb: ⣯ uploading media/images/Pred_Img/Group_Img/486_group_486.png_485_cbf4...
# wandb: ⣯ uploading media/images/Pred_Img/Group_Img/493_group_493.png_492_3e1b...
# wandb: ⣯ uploading media/images/Pred_Img/Group_Img/497_group_497.png_496_575d...
# wandb: ⣯ uploading media/images/Pred_Img/Group_Img/498_group_498.png_497_c81b...
# wandb: ⣯ uploading media/images/Pred_Img/Group_Img/488_group_488.png_487_3c5d...
# wandb: + 12 more task(s)
# wandb:
# wandb: Run summary:
# wandb:       acc 0.56206
# wandb:      dice 0.53082
# wandb:      miou 0.38304
# wandb: precision 0.56874
# wandb:    recall 0.56206
# wandb:
# wandb: 🚀 View run resnet50_8x_cosine_accu_bgmix025_scaler1/predict at: https://wandb.ai/ltc735983415-newcastle-university/CSC8639_FewShot_FoodSeg103/runs/r1xrbily
# wandb: ⭐️ View project at: https://wandb.ai/ltc735983415-newcastle-university/CSC8639_FewShot_FoodSeg103
# wandb: Synced 5 W&B file(s), 500 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250729_223739-r1xrbily/logs
