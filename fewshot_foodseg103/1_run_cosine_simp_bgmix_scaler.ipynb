# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/Colab_Notebooks/CSC8639/fewshot_foodseg103')

# %%
# !pip install segmentation_models_pytorch
# Out:
# Collecting segmentation_models_pytorch
#   Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: huggingface-hub>=0.24 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (0.34.1)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (2.0.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (11.3.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (0.5.3)
# Requirement already satisfied: timm>=0.9 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (1.0.19)
# Requirement already satisfied: torch>=1.8 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (1.1.5)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8->segmentation_models_pytorch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8->segmentation_models_pytorch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8->segmentation_models_pytorch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.24->segmentation_models_pytorch) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.24->segmentation_models_pytorch) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.24->segmentation_models_pytorch) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.24->segmentation_models_pytorch) (2025.7.14)
# Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 5.2 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 124.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 95.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 60.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 42.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 10.8 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 12.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 103.9 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, segmentation_models_pytorch
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 segmentation_models_pytorch-0.5.0

# %%
# Train
# FoodSeg103

args = [
    '--split_class_json', '../data/foodseg103/class_split.json',
    '--class2images_mapping_json', '../data/foodseg103/class2images_mapping.json',
    '--img_dir', '../data/foodseg103/rawdata/image',
    '--mask_dir', '../data/foodseg103/rawdata/mask',

    '--model_name', 'resnet50_8x_cosine_simp_bgmix_scaler',  # 选择模型时更改
    '--seed', '42',
    '--beta_mix', '0.75',
    '--alpha_bg', '1',

    '--n_way', '1',
    '--k_shot', '5',
    '--q_query', '5',
    '--train_episodes', '100',
    '--val_episodes', '50',

    '--batch_size', '1',
    '--num_workers', '10',
    '--epochs', '50',

    '--optimizer', 'adamw',  # adam/adamw/sgd
    '--scheduler', 'cosine',  # step/cosine/cosine_restart/plateau
    '--learning_rate', '1e-3',
    '--weight_decay', '1e-4',
    '--loss', 'ce',  # ce/dice/focal/combo
    # '--bg_weight', '0.8',  # loss中背景类别权重（已在trainshell中禁用）
    '--metric', 'miou', 'dice', 'precision', 'recall', 'acc',  # 启用的metrics

    '--main_metric', 'miou',  # loss/miou/dice/acc  # 指定监控指标（默认为loss），最佳模型保存策略、plateau学习率下降策略、早停策略共用此指标
    # '--early_stopping_patience', '25',  # 设置早停轮数即启用早停

    # '--weight_path',  # 预训练模型/上次训练模型 路径
    # '--is_resume',  # 断点训练
    '--use_amp',

    '--save_dir', 'result_foodseg103/resnet50_8x_cosine_simp_bgmix075_scaler1',  # 每次更改，与 wandb 项目名相同
    '--wandb'  # 设置即启用
    ]

# !python train_shell.py {' '.join(args)}
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: ltc735983415 (ltc735983415-newcastle-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /content/drive/.shortcut-targets-by-id/1fuvwH2wo3q3zusv_klINh1muke4KOxCQ/Colab_Notebooks/CSC8639/fewshot_foodseg103/wandb/run-20250729_214427-1gemagjf
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run resnet50_8x_cosine_simp_bgmix075_scaler1
# wandb: ⭐️ View project at https://wandb.ai/ltc735983415-newcastle-university/CSC8639_FewShot_FoodSeg103
# wandb: 🚀 View run at https://wandb.ai/ltc735983415-newcastle-university/CSC8639_FewShot_FoodSeg103/runs/1gemagjf
# Start training New Model
# [CONFIG] n_way=1, k_shot=5, q_query=5, train_episodes=100, val_episodes=50
#
#
#
# [Epoch 1/50]
# Epoch 1: train_loss=0.4079, val_loss=0.3733, miou=0.0141, dice=0.0273, precision=0.3655, recall=0.0150, acc=0.0150
# Current learning rate: [0.0009990232305719944]
# Model saved to result_foodseg103/resnet50_8x_cosine_simp_bgmix075_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 2/50]
# Epoch 2: train_loss=0.3558, val_loss=0.3752, miou=0.0107, dice=0.0210, precision=0.3826, recall=0.0111, acc=0.0111
# Current learning rate: [0.0009960967771506664]
#
# [Epoch 3/50]
# Epoch 3: train_loss=0.3524, val_loss=0.3524, miou=0.0034, dice=0.0062, precision=0.1865, recall=0.0035, acc=0.0035
# Current learning rate: [0.0009912321891107007]
#
# [Epoch 4/50]
# Epoch 4: train_loss=0.3610, val_loss=0.3505, miou=0.0563, dice=0.1031, precision=0.4594, recall=0.0615, acc=0.0615
# Current learning rate: [0.0009844486647586721]
# Model saved to result_foodseg103/resnet50_8x_cosine_simp_bgmix075_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 5/50]
# Epoch 5: train_loss=0.3185, val_loss=0.3302, miou=0.0347, dice=0.0625, precision=0.4591, recall=0.0369, acc=0.0369
# Current learning rate: [0.0009757729755661009]
#
# [Epoch 6/50]
# Epoch 6: train_loss=0.3245, val_loss=0.3346, miou=0.0752, dice=0.1268, precision=0.4795, recall=0.0927, acc=0.0927
# Current learning rate: [0.0009652393605146842]
# Model saved to result_foodseg103/resnet50_8x_cosine_simp_bgmix075_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 7/50]
# Epoch 7: train_loss=0.3491, val_loss=0.3517, miou=0.0011, dice=0.0022, precision=0.1275, recall=0.0012, acc=0.0012
# Current learning rate: [0.0009528893909706795]
#
# [Epoch 8/50]
# Epoch 8: train_loss=0.3174, val_loss=0.3479, miou=0.0833, dice=0.1429, precision=0.4703, recall=0.1025, acc=0.1025
# Current learning rate: [0.0009387718066217122]
# Model saved to result_foodseg103/resnet50_8x_cosine_simp_bgmix075_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 9/50]
# Epoch 9: train_loss=0.3499, val_loss=0.3164, miou=0.0542, dice=0.0917, precision=0.5553, recall=0.0596, acc=0.0596
# Current learning rate: [0.0009229423231234972]
#
# [Epoch 10/50]
# Epoch 10: train_loss=0.3127, val_loss=0.3226, miou=0.3026, dice=0.4428, precision=0.4520, recall=0.4866, acc=0.4866
# Current learning rate: [0.0009054634122155987]
# Model saved to result_foodseg103/resnet50_8x_cosine_simp_bgmix075_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 11/50]
# Epoch 11: train_loss=0.3039, val_loss=0.3257, miou=0.0924, dice=0.1530, precision=0.4883, recall=0.1057, acc=0.1057
# Current learning rate: [0.0008864040551740153]
#
# [Epoch 12/50]
# Epoch 12: train_loss=0.3152, val_loss=0.3144, miou=0.1923, dice=0.2910, precision=0.5317, recall=0.2456, acc=0.2456
# Current learning rate: [0.0008658394705735984]
#
# [Epoch 13/50]
# Epoch 13: train_loss=0.3210, val_loss=0.2947, miou=0.1985, dice=0.2959, precision=0.4640, recall=0.2601, acc=0.2601
# Current learning rate: [0.0008438508174347006]
#
# [Epoch 14/50]
# Epoch 14: train_loss=0.2979, val_loss=0.2989, miou=0.2754, dice=0.3964, precision=0.4765, recall=0.4075, acc=0.4075
# Current learning rate: [0.000820524874925601]
#
# [Epoch 15/50]
# Epoch 15: train_loss=0.3153, val_loss=0.3066, miou=0.2956, dice=0.4237, precision=0.4509, recall=0.4608, acc=0.4608
# Current learning rate: [0.000795953699884774]
#
# [Epoch 16/50]
# Epoch 16: train_loss=0.3096, val_loss=0.3096, miou=0.3114, dice=0.4420, precision=0.4591, recall=0.4826, acc=0.4826
# Current learning rate: [0.000770234263514603]
# Model saved to result_foodseg103/resnet50_8x_cosine_simp_bgmix075_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 17/50]
# Epoch 17: train_loss=0.3114, val_loss=0.2973, miou=0.2263, dice=0.3361, precision=0.5011, recall=0.3145, acc=0.3145
# Current learning rate: [0.0007434680686803488]
#
# [Epoch 18/50]
# Epoch 18: train_loss=0.3353, val_loss=0.3026, miou=0.2033, dice=0.3051, precision=0.4990, recall=0.2673, acc=0.2673
# Current learning rate: [0.0007157607493247108]
#
# [Epoch 19/50]
# Epoch 19: train_loss=0.2838, val_loss=0.3006, miou=0.2882, dice=0.4152, precision=0.4912, recall=0.4274, acc=0.4274
# Current learning rate: [0.0006872216535789154]
#
# [Epoch 20/50]
# Epoch 20: train_loss=0.2967, val_loss=0.2983, miou=0.2969, dice=0.4239, precision=0.5040, recall=0.4559, acc=0.4559
# Current learning rate: [0.0006579634122155987]
#
# [Epoch 21/50]
# Epoch 21: train_loss=0.2996, val_loss=0.2841, miou=0.2239, dice=0.3333, precision=0.5463, recall=0.2777, acc=0.2777
# Current learning rate: [0.0006281014941466028]
#
# [Epoch 22/50]
# Epoch 22: train_loss=0.2956, val_loss=0.3083, miou=0.3312, dice=0.4685, precision=0.4669, recall=0.5495, acc=0.5495
# Current learning rate: [0.0005977537507199335]
# Model saved to result_foodseg103/resnet50_8x_cosine_simp_bgmix075_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 23/50]
# Epoch 23: train_loss=0.3005, val_loss=0.3149, miou=0.1427, dice=0.2213, precision=0.4641, recall=0.1762, acc=0.1762
# Current learning rate: [0.0005670399506143305]
#
# [Epoch 24/50]
# Epoch 24: train_loss=0.2768, val_loss=0.2793, miou=0.2702, dice=0.3896, precision=0.5245, recall=0.3696, acc=0.3696
# Current learning rate: [0.0005360813071670099]
#
# [Epoch 25/50]
# Epoch 25: train_loss=0.2716, val_loss=0.2875, miou=0.3223, dice=0.4549, precision=0.4857, recall=0.4916, acc=0.4916
# Current learning rate: [0.0005049999999999998]
#
# [Epoch 26/50]
# Epoch 26: train_loss=0.3144, val_loss=0.2893, miou=0.2347, dice=0.3470, precision=0.4933, recall=0.3038, acc=0.3038
# Current learning rate: [0.0004739186928329897]
#
# [Epoch 27/50]
# Epoch 27: train_loss=0.2780, val_loss=0.2763, miou=0.2899, dice=0.4121, precision=0.4938, recall=0.3992, acc=0.3992
# Current learning rate: [0.0004429600493856692]
#
# [Epoch 28/50]
# Epoch 28: train_loss=0.2934, val_loss=0.2939, miou=0.3175, dice=0.4490, precision=0.4680, recall=0.4906, acc=0.4906
# Current learning rate: [0.0004122462492800661]
#
# [Epoch 29/50]
# Epoch 29: train_loss=0.2923, val_loss=0.2894, miou=0.2929, dice=0.4220, precision=0.5085, recall=0.4239, acc=0.4239
# Current learning rate: [0.0003818985058533967]
#
# [Epoch 30/50]
# Epoch 30: train_loss=0.2807, val_loss=0.2760, miou=0.3035, dice=0.4364, precision=0.5329, recall=0.4299, acc=0.4299
# Current learning rate: [0.00035203658778440103]
#
# [Epoch 31/50]
# Epoch 31: train_loss=0.2993, val_loss=0.2884, miou=0.3562, dice=0.4935, precision=0.4791, recall=0.5669, acc=0.5669
# Current learning rate: [0.00032277834642108444]
# Model saved to result_foodseg103/resnet50_8x_cosine_simp_bgmix075_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 32/50]
# Epoch 32: train_loss=0.2905, val_loss=0.2733, miou=0.3246, dice=0.4554, precision=0.5163, recall=0.4629, acc=0.4629
# Current learning rate: [0.0002942392506752889]
#
# [Epoch 33/50]
# Epoch 33: train_loss=0.2713, val_loss=0.2817, miou=0.3166, dice=0.4438, precision=0.4731, recall=0.4616, acc=0.4616
# Current learning rate: [0.00026653193131965077]
#
# [Epoch 34/50]
# Epoch 34: train_loss=0.2759, val_loss=0.2793, miou=0.3277, dice=0.4566, precision=0.4975, recall=0.4922, acc=0.4922
# Current learning rate: [0.00023976573648539642]
#
# [Epoch 35/50]
# Epoch 35: train_loss=0.2882, val_loss=0.2656, miou=0.2870, dice=0.4070, precision=0.5511, recall=0.3756, acc=0.3756
# Current learning rate: [0.00021404630011522574]
#
# [Epoch 36/50]
# Epoch 36: train_loss=0.2890, val_loss=0.2702, miou=0.3369, dice=0.4666, precision=0.4857, recall=0.5004, acc=0.5004
# Current learning rate: [0.00018947512507439847]
#
# [Epoch 37/50]
# Epoch 37: train_loss=0.2913, val_loss=0.2678, miou=0.2630, dice=0.3770, precision=0.5337, recall=0.3519, acc=0.3519
# Current learning rate: [0.000166149182565299]
#
# [Epoch 38/50]
# Epoch 38: train_loss=0.2793, val_loss=0.2712, miou=0.3320, dice=0.4628, precision=0.5274, recall=0.4875, acc=0.4875
# Current learning rate: [0.00014416052942640132]
#
# [Epoch 39/50]
# Epoch 39: train_loss=0.2718, val_loss=0.2676, miou=0.3193, dice=0.4481, precision=0.5046, recall=0.4545, acc=0.4545
# Current learning rate: [0.00012359594482598432]
#
# [Epoch 40/50]
# Epoch 40: train_loss=0.2527, val_loss=0.2632, miou=0.3163, dice=0.4400, precision=0.5081, recall=0.4404, acc=0.4404
# Current learning rate: [0.00010453658778440102]
#
# [Epoch 41/50]
# Epoch 41: train_loss=0.2714, val_loss=0.2620, miou=0.3443, dice=0.4712, precision=0.5053, recall=0.4985, acc=0.4985
# Current learning rate: [8.70576768765026e-05]
#
# [Epoch 42/50]
# Epoch 42: train_loss=0.2847, val_loss=0.2588, miou=0.3123, dice=0.4331, precision=0.5226, recall=0.4227, acc=0.4227
# Current learning rate: [7.12281933782875e-05]
#
# [Epoch 43/50]
# Epoch 43: train_loss=0.2717, val_loss=0.2549, miou=0.3313, dice=0.4531, precision=0.5154, recall=0.4542, acc=0.4542
# Current learning rate: [5.71106090293204e-05]
#
# [Epoch 44/50]
# Epoch 44: train_loss=0.2603, val_loss=0.2594, miou=0.3601, dice=0.4902, precision=0.5210, recall=0.5330, acc=0.5330
# Current learning rate: [4.4760639485315563e-05]
# Model saved to result_foodseg103/resnet50_8x_cosine_simp_bgmix075_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 45/50]
# Epoch 45: train_loss=0.2776, val_loss=0.2524, miou=0.3555, dice=0.4820, precision=0.5200, recall=0.5010, acc=0.5010
# Current learning rate: [3.422702443389899e-05]
#
# [Epoch 46/50]
# Epoch 46: train_loss=0.2747, val_loss=0.2555, miou=0.3601, dice=0.4890, precision=0.5065, recall=0.5284, acc=0.5284
# Current learning rate: [2.5551335241327665e-05]
#
# [Epoch 47/50]
# Epoch 47: train_loss=0.2862, val_loss=0.2555, miou=0.3726, dice=0.5017, precision=0.5223, recall=0.5560, acc=0.5560
# Current learning rate: [1.876781088929908e-05]
# Model saved to result_foodseg103/resnet50_8x_cosine_simp_bgmix075_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 48/50]
# Epoch 48: train_loss=0.2957, val_loss=0.2581, miou=0.3761, dice=0.5059, precision=0.5035, recall=0.5693, acc=0.5693
# Current learning rate: [1.3903222849333505e-05]
# Model saved to result_foodseg103/resnet50_8x_cosine_simp_bgmix075_scaler1/checkpoint/model_best.pth
# Best model updated
#
# [Epoch 49/50]
# Epoch 49: train_loss=0.2772, val_loss=0.2566, miou=0.3433, dice=0.4692, precision=0.5269, recall=0.4805, acc=0.4805
# Current learning rate: [1.0976769428005579e-05]
#
# [Epoch 50/50]
# Epoch 50: train_loss=0.2640, val_loss=0.2562, miou=0.3519, dice=0.4785, precision=0.5121, recall=0.5052, acc=0.5052
# Current learning rate: [1e-05]
# Model saved to result_foodseg103/resnet50_8x_cosine_simp_bgmix075_scaler1/checkpoint/model_final.pth
# wandb:
# wandb:
# wandb: Run history:
# wandb:    Loss/train █▆▅▆▄▅▄▅▄▃▄▃▄▄▄▂▃▃▃▃▂▄▂▃▃▃▃▂▂▃▂▂▁▂▂▁▂▂▃▂
# wandb:      Loss/val ██▇▇▅▇▆▅▅▅▃▄▄▄▄▄▄▃▄▅▃▃▂▃▃▃▂▃▃▂▂▂▂▁▁▁▁▁▁▁
# wandb:       acc/val ▁▁▁▂▁▁▂▂▇▂▄▆▇▇▅▆▇▄█▃▇▅▆▆▆▇▇▆▇▅▇▆▇▆▇▇▇██▇
# wandb:      dice/val ▁▁▁▂▂▁▃▂▇▃▅▇▇▆▅▇▆▇▄▆▆▇▇▇▇▇▇▇▇▇▇▇▇█▇█████
# wandb:      miou/val ▁▁▁▂▂▁▃▂▇▃▅▆▆▇▅▇▅▄▆▇▆▇▆▇█▇▇▆▇▆▇▇▇▇▇█████
# wandb: precision/val ▅▅▂▆▆▁▇█▆▇▇▇▆▆▇▇▇█▇▇▇▇▇▇▇▇▇▇█▇█▇▇▇▇▇▇▇▇▇
# wandb:    recall/val ▁▁▁▂▁▁▂▇▂▄▆▇▇▅▄▇▄█▃▆▅▆▇▆▆▇▇▆▇▅▇▆▇▆▇▇▇██▇
# wandb:
# wandb: Run summary:
# wandb:    Loss/train 0.264
# wandb:      Loss/val 0.25616
# wandb:       acc/val 0.50517
# wandb:      dice/val 0.47854
# wandb:      miou/val 0.35189
# wandb: precision/val 0.51206
# wandb:    recall/val 0.50517
# wandb:
# wandb: 🚀 View run resnet50_8x_cosine_simp_bgmix075_scaler1 at: https://wandb.ai/ltc735983415-newcastle-university/CSC8639_FewShot_FoodSeg103/runs/1gemagjf
# wandb: ⭐️ View project at: https://wandb.ai/ltc735983415-newcastle-university/CSC8639_FewShot_FoodSeg103
# wandb: Synced 5 W&B file(s), 6 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250729_214427-1gemagjf/logs

# %%
# Predict
# FoodSeg103

args = [
    '--split_class_json', '../data/foodseg103/class_split.json',
    '--class2images_mapping_json', '../data/foodseg103/class2images_mapping.json',
    '--img_dir', '../data/foodseg103/rawdata/image',
    '--mask_dir', '../data/foodseg103/rawdata/mask',

    '--model_name', 'resnet50_8x_cosine_simp_bgmix_scaler',  # 选择模型时更改
    '--seed', '42',
    '--beta_mix', '0.75',
    '--alpha_bg', '1',

    '--n_way', '1',
    '--k_shot', '5',
    '--q_query', '5',
    '--pred_episodes', '100',

    '--batch_size', '1',
    '--num_workers', '10',
    '--metric', 'miou', 'dice', 'precision', 'recall', 'acc',

    '--weight_path', 'result_foodseg103/resnet50_8x_cosine_simp_bgmix075_scaler1/checkpoint/model_best.pth',  # 每次更改
    '--use_amp',

    '--save_dir', 'result_foodseg103/resnet50_8x_cosine_simp_bgmix075_scaler1/predict',  # 每次更改，与 wandb 项目名相同
    '--wandb',  # 设置即启用
]

# !python predict_shell.py {' '.join(args)}
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: ltc735983415 (ltc735983415-newcastle-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /content/drive/.shortcut-targets-by-id/1fuvwH2wo3q3zusv_klINh1muke4KOxCQ/Colab_Notebooks/CSC8639/fewshot_foodseg103/wandb/run-20250729_215530-x07blkyi
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run resnet50_8x_cosine_simp_bgmix075_scaler1/predict
# wandb: ⭐️ View project at https://wandb.ai/ltc735983415-newcastle-university/CSC8639_FewShot_FoodSeg103
# wandb: 🚀 View run at https://wandb.ai/ltc735983415-newcastle-university/CSC8639_FewShot_FoodSeg103/runs/x07blkyi
# miou: 0.3667
# dice: 0.5114
# precision: 0.5827
# recall: 0.5476
# acc: 0.5476
#
# Prediction images saved to: result_foodseg103/resnet50_8x_cosine_simp_bgmix075_scaler1/predict
# wandb:
# wandb:
# wandb: Run summary:
# wandb:       acc 0.54759
# wandb:      dice 0.51137
# wandb:      miou 0.36672
# wandb: precision 0.58269
# wandb:    recall 0.54759
# wandb:
# wandb: 🚀 View run resnet50_8x_cosine_simp_bgmix075_scaler1/predict at: https://wandb.ai/ltc735983415-newcastle-university/CSC8639_FewShot_FoodSeg103/runs/x07blkyi
# wandb: ⭐️ View project at: https://wandb.ai/ltc735983415-newcastle-university/CSC8639_FewShot_FoodSeg103
# wandb: Synced 5 W&B file(s), 500 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250729_215530-x07blkyi/logs
